# %%
x = int(input())
y = int(input())

last_digit_of_x = x%10
last_digit_of_y = y%10

print(last_digit_of_x+last_digit_of_y)

# This code give error on codeforces
# It cannot take x and y input in a same line like this (12 14)
# x and y take as a string , so it cannot process type cast
# First we have to split x and y as two different number
# Out:
# 6

# %%
inp = input()
numbers = inp.split()

x = int(numbers[0])
y = int(numbers[1])

last_digit_of_x = x%10
last_digit_of_y = y%10

sum = last_digit_of_x+last_digit_of_y
print(sum)
# Out:
# 5
