# %%
name = input("What is your name?")
print(name)
# Out:
# Hujaifa

# %%
age = input("Enter your age:")
print(age,type(age))
# Out:
# 23 <class 'str'>

# %%
age = input("Age?")# python take input as string

age = int(age) # Convert string to integer
print(age,type(age))
# Out:
# 23 <class 'int'>

# %%
height = input("Height?")
print(height,type(height))

height = height+2.5 # Height is string so give error for adding number
print(height)
# Out:
# 3.3 <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 height = input("Height?")
#       2 print(height,type(height))
#       3
# ----> 4 height = height+2.5 # Height is string so give error for adding number
#       5 print(height)
#
# TypeError: can only concatenate str (not "float") to str

# %%
#height = input("Height?")
#height = float(height) # Convert string to float

height = float(input("Height"))
print(height,type(height))
height = height+2.5 # Height is now float so give error for adding number
print(height)
# Out:
# 4.4 <class 'float'>
# 6.9
