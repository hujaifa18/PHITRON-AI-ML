# %%
phone_number = 12345
print(phone_number)
# Out:
# 12345

# %%
name = "Hujaifa"
print(name)
# Out:
# Hujaifa

# %%
age = 23
name = "Hujaifa"
height = 5.6
is_passed = True
print(type(age),type(name),type(height),type(is_passed))
age = 22.5
print(type(age))
# Out:
# <class 'int'> <class 'str'> <class 'float'> <class 'bool'>
# <class 'float'>
