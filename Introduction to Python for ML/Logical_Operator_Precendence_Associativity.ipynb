# %%
x = 10; y = 7; z = 5
res1 = (x>y) and (x>z)
print(res1)

res2 = (x>y) and (x>11)
print(res2)
# Out:
# True
# False

# %%
x = 10; y = 7; z = 5
res1 = (x>y) or (x>z)
print(res1)

res2 = (x>y) or (x>11)
print(res2)

res3 = (x>20) or (x>11)
print(res3)
# Out:
# True
# True
# False

# %% [markdown]
# ##
# Precendence and Associativity

# %%
eq = 10 + 10/2 - 5*10
print(eq)

# (/ , *) Higher precedence --> left to right
# (+ , -) Lower precedence --> left to right
# Out:
# -35.0
